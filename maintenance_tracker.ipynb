# %%
import streamlit as st
import pandas as pd

# %%
# Step 1: Load data from Google Sheet
# Share your sheet as "Anyone with link can view" and copy the sheet ID
SHEET_ID = "1D2Se_QOfzKjLYLPC7VZ32WGTEhsjEiZcz1PPX08rmU8"
SHEET_NAME = "FY2025-2026"
URL = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/gviz/tq?tqx=out:csv&sheet={SHEET_NAME}"

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Read sheet into DataFrame
df = pd.read_csv(URL, header=0)
df
# Out:
#     Flat No.                  Owner Name    Unnamed: 2 Flat Type  \
# 0      D-101          SANGITA D.CHOUGULE  9.860901e+09      2BHK
# 1      D-102           SAGAR M. MUNNOLLI  8.939340e+09      2BHK
# 2      D-103              SENTHIL KUMAR   6.383732e+09      2BHK
# 3      D-104              PRIYANKA SINGH  9.011037e+09      1BHK
# 4      D-105                 AMOL JADHAV  9.552510e+09      1BHK
# 5      D-106            SHANKAR M. PATIL  9.850951e+09      2BHK
# 6      D-107              SACHIN KUMAWAT  9.822076e+09      2BHK
# 7      D-108        KUMARI VANDANA SINGH  9.262572e+09      1BHK
# 8      D-109                AMOL N. DOKE  9.820142e+09      1BHK
# 9     D-1010             AMIT SANJAY RAJ  9.922950e+09      2BHK
# 10    D-1011                  GOURAB DAS  9.766600e+09      2BHK
# 11    D-1012              AJAY R. SHINDE  9.869723e+09      2BHK
# 12     D-201              ANIL A. JARALI  9.960768e+09      2BHK
# ...

# %%
df.columns
# Out:
# Index(['Flat No.', 'Owner Name', 'Unnamed: 2', 'Flat Type',
#        'Occupied / Rented', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Payment Method', 'Payment Mode', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Additional payment or \nArrears2 (₹)',
#        'Paid On', 'Additional payment or \nArrears3 (₹)', 'Paid On.1',
#        'Waiver', 'Unnamed: 31', 'Unnamed: 32', 'Notes', 'Unnamed: 34',
#        'Payment Status', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42',
#        'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46',
#        'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', '1'],
#       dtype='object')

# %%
from datetime import datetime

# %%
df.columns = [
    'Flat No.',
'Owner Name',
'Contact',
'Flat Type',
'Occupied / Rented',
'Prev. Year Debit (+) /Credit(-) (₹)',
'Total Maint. (₹) (For Current year)',
'One time discounted amount (₹)',
'Payment Method',
'Payment Mode',
'One-Time Payment (₹)',
'Paid On1',
'Installment 1 Due (₹)',
'Paid On2',
'Late Interest 1 (₹)',
'Installment 1 with interest (₹)',
'Installment 2 Due (₹)',
'Paid On3',
'Late Interest  2 (₹)',
'Installment 2 with interest (₹)',
'Installment 3 Due (₹)',
'Paid On4',
'Late Interest 3 (₹)',
'Installment 3 with interest (₹)',
'Additional payment or Arrears1 (₹)',
'Paid On5',
'Additional payment or Arrears2 (₹)',
'Paid On6',
'Additional payment or Arrears3 (₹)',
'Paid On7',
'Waiver',
'Total Paid (₹)',
'Balance (₹)',
'Notes',
'Unnamed: 34',
'Payment Status',
'Current / Previous Balance',
'First installment amount',
'Late payment interest on first installment',
'Second installment amount',
'Late payment interest on Second installment',
'Third installment amount',
'Late payment interest on Third installment',
'Unnamed: 43',
'Unnamed: 44',
'Unnamed: 45',
'1st installment Amount',
'2nd installment Amount',
'3rd installment Amount',
'Unnamed: 49',
'Unnamed: 50',
'1'
]

# %%
df
# Out:
#     Flat No.                  Owner Name       Contact Flat Type  \
# 0      D-101          SANGITA D.CHOUGULE  9.860901e+09      2BHK
# 1      D-102           SAGAR M. MUNNOLLI  8.939340e+09      2BHK
# 2      D-103              SENTHIL KUMAR   6.383732e+09      2BHK
# 3      D-104              PRIYANKA SINGH  9.011037e+09      1BHK
# 4      D-105                 AMOL JADHAV  9.552510e+09      1BHK
# 5      D-106            SHANKAR M. PATIL  9.850951e+09      2BHK
# 6      D-107              SACHIN KUMAWAT  9.822076e+09      2BHK
# 7      D-108        KUMARI VANDANA SINGH  9.262572e+09      1BHK
# 8      D-109                AMOL N. DOKE  9.820142e+09      1BHK
# 9     D-1010             AMIT SANJAY RAJ  9.922950e+09      2BHK
# 10    D-1011                  GOURAB DAS  9.766600e+09      2BHK
# 11    D-1012              AJAY R. SHINDE  9.869723e+09      2BHK
# 12     D-201              ANIL A. JARALI  9.960768e+09      2BHK
# ...

# %%
pip install gspread
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install oauth2client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
